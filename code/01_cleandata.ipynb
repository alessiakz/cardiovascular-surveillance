# %%
#01_cleandata.ipynb
    #this script is used to re-structure, clean and conduct initial data checks of data
#Created: 07.09.2024
#By: Alessia Kettlitz

#importing libraries
import pandas as pd, numpy as np, matplotlib as plt, seaborn as sns, pyprojroot as root

from pyprojroot.here import here #importing here function for relative file paths

from joblib import dump, load #for saving dataframes

# %%
#importing data
data_raw = pd.read_csv(here('Raw_Data/National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data_20240709.csv'))
# Out:
# C:\Users\Alessia\AppData\Local\Temp\ipykernel_7584\132631249.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv(here('Raw_Data/National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data_20240709.csv'))

# %% [markdown]
# ## Initial Data Cleaning

# %%
#printing head of data
data_raw.head(25)
# Out:
#                                        RowId  YearStart LocationAbbr  \
# 0   NVSS~2000~1~NV001~OVR01~Age-Standardized       2000           AL
# 1              NVSS~2000~1~NV001~OVR01~Crude       2000           AL
# 2              NVSS~2000~1~NV001~GEN01~Crude       2000           AL
# 3   NVSS~2000~1~NV001~GEN01~Age-Standardized       2000           AL
# 4   NVSS~2000~1~NV001~GEN02~Age-Standardized       2000           AL
# 5              NVSS~2000~1~NV001~GEN02~Crude       2000           AL
# 6              NVSS~2000~1~NV001~AGE01~Crude       2000           AL
# 7              NVSS~2000~1~NV001~AGE04~Crude       2000           AL
# 8              NVSS~2000~1~NV001~AGE05~Crude       2000           AL
# 9              NVSS~2000~1~NV001~AGE06~Crude       2000           AL
# 10             NVSS~2000~1~NV001~AGE07~Crude       2000           AL
# 11             NVSS~2000~1~NV001~AGE08~Crude       2000           AL
# 12             NVSS~2000~1~NV001~RAC01~Crude       2000           AL
# 13  NVSS~2000~1~NV001~RAC01~Age-Standardized       2000           AL
# 14  NVSS~2000~1~NV001~RAC02~Age-Standardized       2000           AL
# 15             NVSS~2000~1~NV001~RAC02~Crude       2000           AL
# 16  NVSS~2000~1~NV001~RAC04~Age-Standardized       2000           AL
# 17             NVSS~2000~1~NV001~RAC04~Crude       2000           AL
# 18             NVSS~2000~1~NV001~RAC07~Crude       2000           AL
# 19  NVSS~2000~1~NV001~RAC07~Age-Standardized       2000           AL
# 20             NVSS~2000~2~NV001~OVR01~Crude       2000           AK
# 21  NVSS~2000~2~NV001~OVR01~Age-Standardized       2000           AK
# 22  NVSS~2000~2~NV001~GEN01~Age-Standardized       2000           AK
# 23             NVSS~2000~2~NV001~GEN01~Crude       2000           AK
# 24             NVSS~2000~2~NV001~GEN02~Crude       2000           AK
#
#    LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0       Alabama       NVSS           NaN            NaN           NaN
# 1       Alabama       NVSS           NaN            NaN           NaN
# 2       Alabama       NVSS           NaN            NaN           NaN
# 3       Alabama       NVSS           NaN            NaN           NaN
# 4       Alabama       NVSS           NaN            NaN           NaN
# 5       Alabama       NVSS           NaN            NaN           NaN
# 6       Alabama       NVSS           NaN            NaN           NaN
# 7       Alabama       NVSS           NaN            NaN           NaN
# 8       Alabama       NVSS           NaN            NaN           NaN
# 9       Alabama       NVSS           NaN            NaN           NaN
# 10      Alabama       NVSS           NaN            NaN           NaN
# 11      Alabama       NVSS           NaN            NaN           NaN
# 12      Alabama       NVSS           NaN            NaN           NaN
# 13      Alabama       NVSS           NaN            NaN           NaN
# 14      Alabama       NVSS           NaN            NaN           NaN
# 15      Alabama       NVSS           NaN            NaN           NaN
# 16      Alabama       NVSS           NaN            NaN           NaN
# 17      Alabama       NVSS           NaN            NaN           NaN
# 18      Alabama       NVSS           NaN            NaN           NaN
# 19      Alabama       NVSS           NaN            NaN           NaN
# 20       Alaska       NVSS           NaN            NaN           NaN
# 21       Alaska       NVSS           NaN            NaN           NaN
# 22       Alaska       NVSS           NaN            NaN           NaN
# 23       Alaska       NVSS           NaN            NaN           NaN
# 24       Alaska       NVSS           NaN            NaN           NaN
#
#     PriorityArea4                    Class  ... Break_Out_Category  \
# 0             NaN  Cardiovascular Diseases  ...            Overall
# 1             NaN  Cardiovascular Diseases  ...            Overall
# 2             NaN  Cardiovascular Diseases  ...             Gender
# 3             NaN  Cardiovascular Diseases  ...             Gender
# 4             NaN  Cardiovascular Diseases  ...             Gender
# 5             NaN  Cardiovascular Diseases  ...             Gender
# 6             NaN  Cardiovascular Diseases  ...                Age
# 7             NaN  Cardiovascular Diseases  ...                Age
# 8             NaN  Cardiovascular Diseases  ...                Age
# 9             NaN  Cardiovascular Diseases  ...                Age
# 10            NaN  Cardiovascular Diseases  ...                Age
# 11            NaN  Cardiovascular Diseases  ...                Age
# 12            NaN  Cardiovascular Diseases  ...               Race
# 13            NaN  Cardiovascular Diseases  ...               Race
# 14            NaN  Cardiovascular Diseases  ...               Race
# 15            NaN  Cardiovascular Diseases  ...               Race
# 16            NaN  Cardiovascular Diseases  ...               Race
# 17            NaN  Cardiovascular Diseases  ...               Race
# 18            NaN  Cardiovascular Diseases  ...               Race
# 19            NaN  Cardiovascular Diseases  ...               Race
# 20            NaN  Cardiovascular Diseases  ...            Overall
# 21            NaN  Cardiovascular Diseases  ...            Overall
# 22            NaN  Cardiovascular Diseases  ...             Gender
# 23            NaN  Cardiovascular Diseases  ...             Gender
# 24            NaN  Cardiovascular Diseases  ...             Gender
#
#              Break_Out ClassId TopicId  QuestionId  Data_Value_TypeID  \
# 0              Overall      C1      T1       NV001            AgeStdz
# 1              Overall      C1      T1       NV001              Crude
# 2                 Male      C1      T1       NV001              Crude
# 3                 Male      C1      T1       NV001            AgeStdz
# 4               Female      C1      T1       NV001            AgeStdz
# 5               Female      C1      T1       NV001              Crude
# 6                18-24      C1      T1       NV001              Crude
# 7                25-44      C1      T1       NV001              Crude
# 8                45-64      C1      T1       NV001              Crude
# 9                  65+      C1      T1       NV001              Crude
# 10                 35+      C1      T1       NV001              Crude
# 11                 75+      C1      T1       NV001              Crude
# 12  Non-Hispanic White      C1      T1       NV001              Crude
# 13  Non-Hispanic White      C1      T1       NV001            AgeStdz
# 14  Non-Hispanic Black      C1      T1       NV001            AgeStdz
# 15  Non-Hispanic Black      C1      T1       NV001              Crude
# 16            Hispanic      C1      T1       NV001            AgeStdz
# 17            Hispanic      C1      T1       NV001              Crude
# 18               Other      C1      T1       NV001              Crude
# 19               Other      C1      T1       NV001            AgeStdz
# 20             Overall      C1      T1       NV001              Crude
# 21             Overall      C1      T1       NV001            AgeStdz
# 22                Male      C1      T1       NV001            AgeStdz
# 23                Male      C1      T1       NV001              Crude
# 24              Female      C1      T1       NV001              Crude
#
#    BreakOutCategoryId BreakOutId  LocationId                       Geolocation
# 0               BOC01      OVR01           1  POINT (-86.63186076 32.84057112)
# 1               BOC01      OVR01           1  POINT (-86.63186076 32.84057112)
# 2               BOC02      GEN01           1  POINT (-86.63186076 32.84057112)
# 3               BOC02      GEN01           1  POINT (-86.63186076 32.84057112)
# 4               BOC02      GEN02           1  POINT (-86.63186076 32.84057112)
# 5               BOC02      GEN02           1  POINT (-86.63186076 32.84057112)
# 6               BOC03      AGE01           1  POINT (-86.63186076 32.84057112)
# 7               BOC03      AGE04           1  POINT (-86.63186076 32.84057112)
# 8               BOC03      AGE05           1  POINT (-86.63186076 32.84057112)
# 9               BOC03      AGE06           1  POINT (-86.63186076 32.84057112)
# 10              BOC03      AGE07           1  POINT (-86.63186076 32.84057112)
# 11              BOC03      AGE08           1  POINT (-86.63186076 32.84057112)
# 12              BOC04      RAC01           1  POINT (-86.63186076 32.84057112)
# 13              BOC04      RAC01           1  POINT (-86.63186076 32.84057112)
# 14              BOC04      RAC02           1  POINT (-86.63186076 32.84057112)
# 15              BOC04      RAC02           1  POINT (-86.63186076 32.84057112)
# 16              BOC04      RAC04           1  POINT (-86.63186076 32.84057112)
# 17              BOC04      RAC04           1  POINT (-86.63186076 32.84057112)
# 18              BOC04      RAC07           1  POINT (-86.63186076 32.84057112)
# 19              BOC04      RAC07           1  POINT (-86.63186076 32.84057112)
# 20              BOC01      OVR01           2   POINT (-147.722059 64.84507996)
# 21              BOC01      OVR01           2   POINT (-147.722059 64.84507996)
# 22              BOC02      GEN01           2   POINT (-147.722059 64.84507996)
# 23              BOC02      GEN01           2   POINT (-147.722059 64.84507996)
# 24              BOC02      GEN02           2   POINT (-147.722059 64.84507996)
#
# [25 rows x 30 columns]

# %%
#checking info of data
data_raw.info()
    #174,720 observations
    #30 variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174720 entries, 0 to 174719
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RowId                       174720 non-null  object
#  1   YearStart                   174720 non-null  int64
#  2   LocationAbbr                174720 non-null  object
#  3   LocationDesc                174720 non-null  object
#  4   DataSource                  174720 non-null  object
#  5   PriorityArea1               43680 non-null   object
#  6   PriorityArea2               0 non-null       float64
#  7   PriorityArea3               43680 non-null   object
#  8   PriorityArea4               0 non-null       float64
#  9   Class                       174720 non-null  object
#  10  Topic                       174720 non-null  object
#  11  Question                    174720 non-null  object
#  12  Data_Value_Type             174720 non-null  object
#  13  Data_Value_Unit             174720 non-null  object
#  14  Data_Value                  143090 non-null  float64
#  15  Data_Value_Alt              174720 non-null  float64
#  16  Data_Value_Footnote_Symbol  31630 non-null   object
#  17  Data_Value_Footnote         31630 non-null   object
#  18  Low_Confidence_Limit        143090 non-null  float64
#  19  High_Confidence_Limit       143090 non-null  float64
#  20  Break_Out_Category          174720 non-null  object
#  21  Break_Out                   174720 non-null  object
#  22  ClassId                     174720 non-null  object
#  23  TopicId                     174720 non-null  object
#  24  QuestionId                  174720 non-null  object
#  25  Data_Value_TypeID           174720 non-null  object
#  26  BreakOutCategoryId          174720 non-null  object
#  27  BreakOutId                  174720 non-null  object
#  28  LocationId                  174720 non-null  int64
#  29  Geolocation                 171360 non-null  object
# dtypes: float64(6), int64(2), object(22)
# memory usage: 40.0+ MB

# %%
#basic stats for all variables in dataframe
data_raw.describe(include='all')
# Out:
#                                             RowId      YearStart LocationAbbr  \
# count                                      174720  174720.000000       174720
# unique                                     174720            NaN           52
# top     NVSS~2020~59~NV008~GEN01~Age-Standardized            NaN           AL
# freq                                            1            NaN         3360
# mean                                          NaN    2010.000000          NaN
# std                                           NaN       6.055318          NaN
# min                                           NaN    2000.000000          NaN
# 25%                                           NaN    2005.000000          NaN
# 50%                                           NaN    2010.000000          NaN
# 75%                                           NaN    2015.000000          NaN
# max                                           NaN    2020.000000          NaN
#
#        LocationDesc DataSource PriorityArea1  PriorityArea2  \
# count        174720     174720         43680            0.0
# unique           52          1             1            NaN
# top         Alabama       NVSS          none            NaN
# freq           3360     174720         43680            NaN
# mean            NaN        NaN           NaN            NaN
# std             NaN        NaN           NaN            NaN
# min             NaN        NaN           NaN            NaN
# 25%             NaN        NaN           NaN            NaN
# 50%             NaN        NaN           NaN            NaN
# 75%             NaN        NaN           NaN            NaN
# max             NaN        NaN           NaN            NaN
#
#               PriorityArea3  PriorityArea4                    Class  ...  \
# count                 43680            0.0                   174720  ...
# unique                    1            NaN                        1  ...
# top     Healthy People 2030            NaN  Cardiovascular Diseases  ...
# freq                  43680            NaN                   174720  ...
# mean                    NaN            NaN                      NaN  ...
# std                     NaN            NaN                      NaN  ...
# min                     NaN            NaN                      NaN  ...
# 25%                     NaN            NaN                      NaN  ...
# 50%                     NaN            NaN                      NaN  ...
# 75%                     NaN            NaN                      NaN  ...
# max                     NaN            NaN                      NaN  ...
#
#        Break_Out_Category Break_Out ClassId TopicId  QuestionId  \
# count              174720    174720  174720  174720      174720
# unique                  4        13       1       6           8
# top                  Race   Overall      C1      T6       NV001
# freq                69888     17472  174720   65520       21840
# mean                  NaN       NaN     NaN     NaN         NaN
# std                   NaN       NaN     NaN     NaN         NaN
# min                   NaN       NaN     NaN     NaN         NaN
# 25%                   NaN       NaN     NaN     NaN         NaN
# 50%                   NaN       NaN     NaN     NaN         NaN
# 75%                   NaN       NaN     NaN     NaN         NaN
# max                   NaN       NaN     NaN     NaN         NaN
#
#         Data_Value_TypeID BreakOutCategoryId BreakOutId     LocationId  \
# count              174720             174720     174720  174720.000000
# unique                  2                  4         13            NaN
# top                 Crude              BOC04      OVR01            NaN
# freq               113568              69888      17472            NaN
# mean                  NaN                NaN        NaN      29.538462
# std                   NaN                NaN        NaN      16.064174
# min                   NaN                NaN        NaN       1.000000
# 25%                   NaN                NaN        NaN      16.750000
# 50%                   NaN                NaN        NaN      29.500000
# 75%                   NaN                NaN        NaN      42.500000
# max                   NaN                NaN        NaN      59.000000
#
#                              Geolocation
# count                             171360
# unique                                51
# top     POINT (-86.63186076 32.84057112)
# freq                                3360
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
# [11 rows x 30 columns]

# %%
#filtering dataset to where RowId contains string 'Age-Standardized' - we will subset just to standardized estimates by age
data_filter = data_raw[(data_raw['RowId'].str.contains('Age-Standardized')) & (data_raw['BreakOutId'] == 'OVR01')]

data_filter
#this reduces to 8736 rows - more manageable for this project for now!
# Out:
#                                             RowId  YearStart LocationAbbr  \
# 0        NVSS~2000~1~NV001~OVR01~Age-Standardized       2000           AL
# 21       NVSS~2000~2~NV001~OVR01~Age-Standardized       2000           AK
# 40       NVSS~2000~4~NV001~OVR01~Age-Standardized       2000           AZ
# 61       NVSS~2000~5~NV001~OVR01~Age-Standardized       2000           AR
# 80       NVSS~2000~6~NV001~OVR01~Age-Standardized       2000           CA
# ...                                           ...        ...          ...
# 174621  NVSS~2020~53~NV008~OVR01~Age-Standardized       2020           WA
# 174641  NVSS~2020~54~NV008~OVR01~Age-Standardized       2020           WV
# 174660  NVSS~2020~55~NV008~OVR01~Age-Standardized       2020           WI
# 174681  NVSS~2020~56~NV008~OVR01~Age-Standardized       2020           WY
# 174700  NVSS~2020~59~NV008~OVR01~Age-Standardized       2020           US
#
#          LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0             Alabama       NVSS           NaN            NaN           NaN
# 21             Alaska       NVSS           NaN            NaN           NaN
# 40            Arizona       NVSS           NaN            NaN           NaN
# 61           Arkansas       NVSS           NaN            NaN           NaN
# 80         California       NVSS           NaN            NaN           NaN
# ...               ...        ...           ...            ...           ...
# 174621     Washington       NVSS           NaN            NaN           NaN
# 174641  West Virginia       NVSS           NaN            NaN           NaN
# 174660      Wisconsin       NVSS           NaN            NaN           NaN
# 174681        Wyoming       NVSS           NaN            NaN           NaN
# 174700  United States       NVSS           NaN            NaN           NaN
#
#         PriorityArea4                    Class  ... Break_Out_Category  \
# 0                 NaN  Cardiovascular Diseases  ...            Overall
# 21                NaN  Cardiovascular Diseases  ...            Overall
# 40                NaN  Cardiovascular Diseases  ...            Overall
# 61                NaN  Cardiovascular Diseases  ...            Overall
# 80                NaN  Cardiovascular Diseases  ...            Overall
# ...               ...                      ...  ...                ...
# 174621            NaN  Cardiovascular Diseases  ...            Overall
# 174641            NaN  Cardiovascular Diseases  ...            Overall
# 174660            NaN  Cardiovascular Diseases  ...            Overall
# 174681            NaN  Cardiovascular Diseases  ...            Overall
# 174700            NaN  Cardiovascular Diseases  ...            Overall
#
#        Break_Out ClassId TopicId  QuestionId  Data_Value_TypeID  \
# 0        Overall      C1      T1       NV001            AgeStdz
# 21       Overall      C1      T1       NV001            AgeStdz
# 40       Overall      C1      T1       NV001            AgeStdz
# 61       Overall      C1      T1       NV001            AgeStdz
# 80       Overall      C1      T1       NV001            AgeStdz
# ...          ...     ...     ...         ...                ...
# 174621   Overall      C1      T6       NV008            AgeStdz
# 174641   Overall      C1      T6       NV008            AgeStdz
# 174660   Overall      C1      T6       NV008            AgeStdz
# 174681   Overall      C1      T6       NV008            AgeStdz
# 174700   Overall      C1      T6       NV008            AgeStdz
#
#        BreakOutCategoryId BreakOutId  LocationId  \
# 0                   BOC01      OVR01           1
# 21                  BOC01      OVR01           2
# 40                  BOC01      OVR01           4
# 61                  BOC01      OVR01           5
# 80                  BOC01      OVR01           6
# ...                   ...        ...         ...
# 174621              BOC01      OVR01          53
# 174641              BOC01      OVR01          54
# 174660              BOC01      OVR01          55
# 174681              BOC01      OVR01          56
# 174700              BOC01      OVR01          59
#
#                              Geolocation
# 0       POINT (-86.63186076 32.84057112)
# 21       POINT (-147.722059 64.84507996)
# 40      POINT (-111.7638113 34.86597028)
# 61      POINT (-92.27449074 34.74865012)
# 80      POINT (-120.9999995 37.63864012)
# ...                                  ...
# 174621  POINT (-120.4700108 47.52227863)
# 174641   POINT (-80.71264013 38.6655102)
# 174660  POINT (-89.81637074 44.39319117)
# 174681  POINT (-108.1098304 43.23554134)
# 174700                               NaN
#
# [8736 rows x 30 columns]

# %%
#drop columns that will not be used
columns_to_drop = ['DataSource', 'PriorityArea1', 'PriorityArea2', 'PriorityArea3', 'PriorityArea4', 'Class', 'Break_Out_Category', 'Break_Out', 'ClassId', 'Data_Value_TypeID', 'BreakOutCategoryId', 'BreakOutId']
data_filter.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\Alessia\AppData\Local\Temp\ipykernel_7584\1086600172.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.drop(columns=columns_to_drop, inplace=True)

# %%
#compute descriptive statistics grouped by 'Question'
stats_by_question = data_filter.groupby(['YearStart', 'LocationAbbr', 'Question'])['Data_Value'].describe()

stats_by_question
# Out:
#                                                                            count  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...    1.0
#                        Cerebrovascular disease (stroke) mortality rate...    1.0
#                        Coronary heart disease mortality rate among US ...    1.0
#                        Diseases of the heart (heart disease) mortality...    1.0
#                        Heart failure mortality rate among US adults (1...    1.0
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...    1.0
#                        Heart failure mortality rate among US adults (1...    1.0
#                        Hemorrhagic stroke mortality rate among US adul...    1.0
#                        Ischemic stroke mortality rate among US adults ...    1.0
#                        Major cardiovascular disease mortality rate amo...    1.0
#
#                                                                             mean  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
#                                                                            std  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...  NaN
#                        Cerebrovascular disease (stroke) mortality rate...  NaN
#                        Coronary heart disease mortality rate among US ...  NaN
#                        Diseases of the heart (heart disease) mortality...  NaN
#                        Heart failure mortality rate among US adults (1...  NaN
# ...                                                                        ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  NaN
#                        Heart failure mortality rate among US adults (1...  NaN
#                        Hemorrhagic stroke mortality rate among US adul...  NaN
#                        Ischemic stroke mortality rate among US adults ...  NaN
#                        Major cardiovascular disease mortality rate amo...  NaN
#
#                                                                              min  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
#                                                                              25%  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
#                                                                              50%  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
#                                                                              75%  \
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
#                                                                              max
# YearStart LocationAbbr Question
# 2000      AK           Acute myocardial infarction (heart attack) mort...   46.1
#                        Cerebrovascular disease (stroke) mortality rate...   65.0
#                        Coronary heart disease mortality rate among US ...  149.4
#                        Diseases of the heart (heart disease) mortality...  221.2
#                        Heart failure mortality rate among US adults (1...   18.5
# ...                                                                          ...
# 2020      WY           Diseases of the heart (heart disease) mortality...  197.5
#                        Heart failure mortality rate among US adults (1...   23.0
#                        Hemorrhagic stroke mortality rate among US adul...   11.0
#                        Ischemic stroke mortality rate among US adults ...   19.4
#                        Major cardiovascular disease mortality rate amo...  249.6
#
# [8736 rows x 8 columns]

# %%
#export dataframe to joblib file
dump(data_filter, here('Clean_Data/data.joblib'))
# Out:
# ['c:\\Users\\Alessia\\Documents\\Personal Data Projects\\Python Example\\cardiovascular-surveillance\\Clean_Data\\data.joblib']

# %% [markdown]
#  ## Exploratory Data Analysis

# %% [markdown]
# Checking for Missing Values

# %%
# checking for missing values
data_filter.isnull().sum()

#no concerning missing values - expected as this a government dataset published on the web
# Out:
# RowId                            0
# YearStart                        0
# LocationAbbr                     0
# LocationDesc                     0
# Topic                            0
# Question                         0
# Data_Value_Type                  0
# Data_Value_Unit                  0
# Data_Value                       0
# Data_Value_Alt                   0
# Data_Value_Footnote_Symbol    8736
# Data_Value_Footnote           8736
# Low_Confidence_Limit             0
# High_Confidence_Limit            0
# TopicId                          0
# QuestionId                       0
# LocationId                       0
# Geolocation                    168
# dtype: int64

# %%
#finding the top 5 data values
data_filter.nlargest(5, "Data_Value")
# Out:
#                                           RowId  YearStart LocationAbbr  \
# 480   NVSS~2000~28~NV001~OVR01~Age-Standardized       2000           MS
# 1520  NVSS~2001~28~NV001~OVR01~Age-Standardized       2001           MS
# 2560  NVSS~2002~28~NV001~OVR01~Age-Standardized       2002           MS
# 720   NVSS~2000~40~NV001~OVR01~Age-Standardized       2000           OK
# 2800  NVSS~2002~40~NV001~OVR01~Age-Standardized       2002           OK
#
#      LocationDesc                         Topic  \
# 480   Mississippi  Major Cardiovascular Disease
# 1520  Mississippi  Major Cardiovascular Disease
# 2560  Mississippi  Major Cardiovascular Disease
# 720      Oklahoma  Major Cardiovascular Disease
# 2800     Oklahoma  Major Cardiovascular Disease
#
#                                                Question   Data_Value_Type  \
# 480   Major cardiovascular disease mortality rate am...  Age-Standardized
# 1520  Major cardiovascular disease mortality rate am...  Age-Standardized
# 2560  Major cardiovascular disease mortality rate am...  Age-Standardized
# 720   Major cardiovascular disease mortality rate am...  Age-Standardized
# 2800  Major cardiovascular disease mortality rate am...  Age-Standardized
#
#        Data_Value_Unit  Data_Value  Data_Value_Alt Data_Value_Footnote_Symbol  \
# 480   Rate per 100,000       575.9           575.9                        NaN
# 1520  Rate per 100,000       561.5           561.5                        NaN
# 2560  Rate per 100,000       556.2           556.2                        NaN
# 720   Rate per 100,000       551.6           551.6                        NaN
# 2800  Rate per 100,000       534.0           534.0                        NaN
#
#      Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit TopicId  \
# 480                  NaN                 575.9                  575.9      T1
# 1520                 NaN                 561.5                  561.5      T1
# 2560                 NaN                 556.2                  556.2      T1
# 720                  NaN                 551.6                  551.6      T1
# 2800                 NaN                 534.0                  534.0      T1
#
#      QuestionId  LocationId                       Geolocation
# 480       NV001          28   POINT (-89.53803082 32.7455101)
# 1520      NV001          28   POINT (-89.53803082 32.7455101)
# 2560      NV001          28   POINT (-89.53803082 32.7455101)
# 720       NV001          40  POINT (-97.52107021 35.47203136)
# 2800      NV001          40  POINT (-97.52107021 35.47203136)
